# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # About Features
#
# 1. **Employee ID**: A unique identifier for each employee. Usually a numeric or alphanumeric code.
#
# 2. **Name**: The full name of the employee. This might be split into first and last names in some datasets.
#
# 3. **Department**: The department or division within the organization where the employee works.
#
# 4. **Job Title**: The official title or position held by the employee in the organization.
#
# 5. **Salary**: The amount of money the employee earns. This could be represented as an annual salary, hourly wage, or monthly pay.
#
# 6. **Hire Date**: The date when the employee started working at the organization. Useful for calculating tenure or experience.
#
# 7. **Gender**: The gender of the employee. This might be included in some datasets for diversity and equality analysis.
#
# 8. **Years of Experience**: The total number of years the employee has worked in their field or profession.
#
# 9. **Education Level**: The highest level of education attained by the employee, such as a high school diploma, bachelor's degree, etc.
#
# 10. **Performance Rating**: If available, this could be a measure of the employee's performance in their role, often based on annual review scores.
#
# 11. **Location**: The geographical location or office where the employee works, if the organization has multiple locations.

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('./Salaries.csv')

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency'],
#       dtype='object')

# %% [markdown]
# ### 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.

# %%
# numbers for rows and columns
rows = len(df)
cols = len(df.columns)
print(f"rows = {rows} \ncols = {cols}")
# Out:
# rows = 148654
# cols = 12

# %%
# another way
row = df.shape[0]
column = df.shape[1]
print(f"rows = {row} \ncols = {column}")
# Out:
# rows = 148654
# cols = 12

# %%
# data type of each column
dtype = df.dtypes
dtype
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# dtype: object

# %%
# Counting nan value in each column.
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# dtype: int64

# %% [markdown]
# ### Descriptive Statistics: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.

# %%
salary = df["TotalPayBenefits"]
print(f"max value : {salary.max()}")
print(f"min value : {salary.min()}")
print(f"mean value : {salary.mean()}")
print(f"median value : {salary.median()}")
print(f"std value : {salary.std()}")
print(f"range \"value : {salary.max()-salary.min()}")
print(f"mode value : {salary.mode()}")
# Out:
# max value : 567595.43
# min value : -618.13
# mean value : 93692.55481056834
# median value : 92404.09
# std value : 62793.53348323814
# range "value : 568213.56
# mode value : 0    7959.18
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.

# %%
clean_df = df.loc[df["EmployeeName"] != "Not provided"].dropna(axis=1,how='all').fillna(0)
# I use dropna() func to remove "Note" column because it always empty
# then I use fillna() func to fill all nan numeric fields with 0 and remove not neccessary one and don't effect them on statistics
clean_df = clean_df.loc[clean_df["TotalPayBenefits"] != 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 clean_df = df.loc[df["EmployeeName"] != "Not provided"].dropna(axis=1,how='all').fillna(0)
#       2 # I use dropna() func to remove "Note" column because it always empty
#       3 clean_df = clean_df.loc[clean_df["TotalPayBenefits"] != 0]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(clean_df.TotalPayBenefits,color='#abcdef')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 plt.hist(df.TotalPayBenefits,color='#abcdef')
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
clean_df["count"] = 1
emp_dep = clean_df.groupby(["JobTitle"]).count()["count"].tolist()
emp_dep
# Out:
# [83,
#  5,
#  48,
#  1,
#  1,
#  93,
#  2,
#  2,
#  10,
#  3,
#  1,
#  6,
#  2,
#  1,
#  1,
#  27,
#  2,
#  13,
#  17,
#  2,
#  2,
#  1,
#  2,
#  12,
#  187,
#  13,
#  40,
#  25,
#  1,
#  14,
#  1,
#  13,
#  3,
#  4,
#  11,
#  12,
#  13,
#  6,
#  15,
#  4,
#  2,
#  19,
#  13,
#  20,
#  1,
#  11,
#  10,
#  8,
#  1,
#  26,
#  60,
#  41,
#  36,
#  1,
#  23,
#  5,
#  4,
#  3,
#  5,
#  5,
#  7,
#  6,
#  4,
#  1,
#  5,
#  2,
#  1,
#  1,
#  1,
#  1,
#  11,
#  146,
#  6,
#  6,
#  8,
#  1,
#  1,
#  10,
#  9,
#  1,
#  12,
#  5,
#  2,
#  23,
#  2,
#  1,
#  7,
#  26,
#  2,
#  15,
#  1,
#  1,
#  8,
#  17,
#  148,
#  1,
#  1,
#  2,
#  11,
#  1,
#  1,
#  377,
#  1,
#  2,
#  1,
#  2,
#  38,
#  1,
#  66,
#  8,
#  7,
#  126,
#  11,
#  6,
#  110,
#  4,
#  5,
#  267,
#  8,
#  226,
#  278,
#  171,
#  60,
#  3,
#  3,
#  6,
#  31,
#  368,
#  2,
#  3,
#  29,
#  1,
#  11,
#  2,
#  164,
#  6,
#  85,
#  2,
#  38,
#  50,
#  6,
#  9,
#  2,
#  8,
#  39,
#  36,
#  128,
#  6,
#  66,
#  3,
#  46,
#  2,
#  38,
#  3,
# ...

# %%
plt.figure(figsize=(32,20))
plt.pie(emp_dep,autopct='%.2f %%')
# Out:
# ([<matplotlib.patches.Wedge at 0x18beafe03a0>,
# ...
#   ...],
#  [Text(1.099998307063744, 0.0019298852031676928, ''),
#   Text(1.0999928141808653, 0.003976021939168658, ''),
#   Text(1.0999876695262427, 0.005208348128298459, ''),
#   Text(1.0999816849280686, 0.006347662783057004, ''),
#   Text(1.0999814155931391, 0.006394165286707904, ''),
#   Text(1.0999665392969074, 0.008579768480880304, ''),
#   Text(1.099947092528495, 0.010788588327976007, ''),
#   Text(1.0999461764062521, 0.010881590383139298, ''),
#   Text(1.0999433808587997, 0.01116059608236129, ''),
#   Text(1.0999402724860916, 0.011462851443791076, ''),
#   Text(1.0999392993539827, 0.011555852918328524, ''),
#   Text(1.0999375774514852, 0.0117186052991908, ''),
#   Text(1.099935580075197, 0.011904607706258796, ''),
#   Text(1.0999348229499655, 0.011974358522608624, ''),
#   Text(1.0999343157425074, 0.0120208590401079, ''),
#   Text(1.0999270084252595, 0.012671863977309898, ''),
# ...

# %% [markdown]
# ### 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.

# %% [markdown]
# #### grouped by job title

# %%
clean_df.groupby(["JobTitle"]).describe()["TotalPayBenefits"]

# %%
clean_df.groupby(["JobTitle"]).mean()["TotalPayBenefits"]
# Out:
# JobTitle
# ACCOUNT CLERK                                     44035.664337
# ACCOUNTANT                                        47429.268000
# ACCOUNTANT INTERN                                 29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                       80266.370000
# ACUPUNCTURIST                                     67594.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             52705.880385
# X-Ray Laboratory Aide                             69521.123200
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.870000
# Youth Comm Advisor                                60118.550000
# ZOO CURATOR                                       66686.560000
# Name: TotalPayBenefits, Length: 2158, dtype: float64

# %% [markdown]
# #### grouped by years

# %%
df.groupby(["Year"]).mean()["TotalPayBenefits"]

# %%
df.groupby(["Year"]).describe()["TotalPayBenefits"]
# Out:
# -----------------------------------------
#         count           mean           std     min         25%         50%  \
# Year
# 2011  36159.0   71744.103871  47498.706594    0.00  36810.7600   68213.240
# 2012  36766.0  100553.229232  63555.796681    1.91  51743.0925  101751.290
# 2013  37606.0  101440.519714  66390.034642  -33.89  48259.6000  101969.445
# 2014  38123.0  100250.918884  66238.852887 -618.13  44199.9900  101105.370
#
#               75%        max
# Year
# 2011  102512.6800  567595.43
# 2012  142396.3325  407274.78
# 2013  142793.6875  425815.28
# 2014  142746.9500  510732.68

# %% [markdown]
# ### 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.

# %%
plt.figure(figsize=(8,5))
plt.title('max salary in each year', fontdict={'fontweight':'bold', 'fontsize': 18})
plt.xlabel('Year')
plt.ylabel('max salary')
max_year = list(clean_df.groupby(['Year']).max()["TotalPayBenefits"])
years = list(set(df["Year"]))
plt.scatter(years,max_year)

# %% [markdown]
# # Report:
# ## Task1:
#
#     1-I used len() func with dataframe(df) to calculate the number of rows, I use the same func with df.columns
#     to calculate the number of columns.
#     I solved it using another way by using shape method shape : df.shpe[0] for rows , df.shpa[1] for columns.
#     2- I showed the data type of each column using dtypes attribute :df.dtypes
#     3- To count the number of nan field in each column I used isnull method to give bool value to each empty field then I counted them using sum func:df.isnull().sum()
#
# ## Task2:
#     1- I calculated all statistics operations using the suitable method to calculate them.
#
# ### Task3:
#     1- firstly I shifted empty name and job title rows then I dropped empty column"Notes" after that I fill all nan numeric fields by o.
#     2- I shifted all rows that its salary is 0 to avoid any incorrect results in graphs or statistics operations.
#
# ### Task4:
#     1- I used matplot library to drawing graphs.
#     2- for histgram I put first arg is salary to show how its values are distribute .
#     3- In pie chart first arg should be list so I count the number of employes in each department and put them in the list called emp_dep then I used autopct arg to calculate the proporation.
#
# ### Task5:
#     1- I grouped  data by department then I gave a summary of statistic by using "describe()" method and I calculated mean of salary.
#     2- I grouped  data  by year then I gave a summary of statistic by using "describe()" method and I calculated mean of salary.
#
# ### Task6:
#     I showed the correlation between max salary and year by scatter chart.
